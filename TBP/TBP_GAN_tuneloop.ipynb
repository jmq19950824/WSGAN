# %%
import pandas as pd
import numpy as np
import random

#split dataset
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

#AUCROC,AUCPR,precision,recall,f1-score
from sklearn.metrics import roc_curve,auc,average_precision_score,precision_score,recall_score,f1_score

#gridsearch/randomsearch
from itertools import product
from tqdm import tqdm

#visualize results
import matplotlib.pyplot as plt
import time

# %%
import torch
import torchvision
from torch import nn
from torch.autograd import Variable
from torch.utils.data import Subset,DataLoader,TensorDataset
from torchvision import datasets,transforms
import torch.nn.functional as F

# %%
# import warnings
# warnings.filterwarnings("ignore")

if torch.cuda.is_available():
  is_cuda=True
  print('GPU is on')
else:
  is_cuda=False
  print('GPU is off')
# Out:
# GPU is off

# %%
def set_seed(seed):
  np.random.seed(seed)
  torch.manual_seed(seed)
  random.seed(seed)

  torch.backends.cudnn.deterministic = True
  torch.backends.cudnn.benchmark = False

# %%
def data_prepare(batch_size,contam_ratio,hybrid,seed):
    set_seed(seed)
    data = pd.read_csv("E:/Research_Anomaly Detection/Taiwanese Bankruptcy Prediction (TBP)/data/TBP_select.csv")
    #change 0,1 label to 1,-1
    data.loc[data['Flag'] == 1,'Flag'] = -1
    data.loc[data['Flag'] == 0,'Flag'] = 1

    X = np.array(data.drop(['Flag'], axis = 1))
    #X = np.array(data.iloc[:,1:20])
    y = np.array(data['Flag'].values)
    
    #reverse
    scaler = MinMaxScaler().fit(X)
    X = scaler.inverse_transform(X)

    #split the data to training, validation and testing data (50%,20%,30%)
    X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.3,shuffle = False)
    X_train,X_val,y_train,y_val = train_test_split(X_train,y_train,test_size = 2/7,shuffle = False)

#     X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.3,shuffle = True,stratify = y)
#     X_train,X_val,y_train,y_val = train_test_split(X_train,y_train,test_size = 1/7,shuffle = True,stratify = y_train)

    #the known positive samples before contaminating
    known_pos_entire = sum(y_train == -1)
    #Minmax
    scaler=MinMaxScaler().fit(X_train)

    X_train = scaler.transform(X_train)
    X_val = scaler.transform(X_val)
    X_test = scaler.transform(X_test)

    index_contam = np.arange(len(y_train))[y_train == -1]
    index_contam = np.random.choice(index_contam,int(contam_ratio*len(index_contam)),replace = False)

    y_train[index_contam] = 1
    #the known positive samples after contaminating
    known_pos_sub = sum(y_train == -1)

    print(f'The left true(known) positive samples in the training set:{known_pos_sub}/{known_pos_entire}\n')
    #normal training tensor and dataloader
    #none-hybrid model only use "normal" samples in the training phase, which could be contaminated
    if not hybrid:
        index_subset = np.arange(len(y_train))[y_train == 1]
    else:
        index_subset = np.arange(len(y_train))
    

    #transform numpy to pytorch tensor
    train_tensor = TensorDataset(torch.from_numpy(X_train).float(),torch.tensor(y_train))
    train_tensor = Subset(train_tensor,index_subset)
    #fitting by batches (using dataloader), there exists randomness when shuffle=True***
    train_loader=DataLoader(train_tensor,batch_size = batch_size,shuffle = False,drop_last = True)
    
    #validation set
    X_val_tensor = torch.from_numpy(X_val).float()
    #testing set
    X_test_tensor=torch.from_numpy(X_test).float()
    
    return train_loader,X_val_tensor,y_val,X_test_tensor,y_test

# %%
class generator(nn.Module):
  def __init__(self,input_size,act_fun):
    super(generator,self).__init__()

    self.encoder_1=nn.Sequential(
      nn.Linear(input_size,input_size//4),
      act_fun,
      )
    
    self.decoder_1=nn.Sequential(
      nn.Linear(input_size//4,input_size),
      )

    self.encoder_2=nn.Sequential(
      nn.Linear(input_size,input_size//4),
      act_fun,
      )

  def forward(self,input):
    z=self.encoder_1(input)
    X_hat=self.decoder_1(z)
    z_hat=self.encoder_2(X_hat)

    return z,X_hat,z_hat

# %%
class discriminator(nn.Module):
  def __init__(self,input_size,act_fun):
    super(discriminator,self).__init__()

    self.encoder=nn.Sequential(
        nn.Linear(input_size,input_size//4),
        act_fun,
        )

    self.classifier=nn.Sequential(
        nn.Linear(input_size//4,1),
        nn.Sigmoid()
        )
    
  def forward(self,input):
    latent_vector = self.encoder(input)
    output = self.classifier(latent_vector)

    return latent_vector,output

# %%
def fit(dataloader,net_generator,net_discriminator,epochs,batch_size,print_loss):
  L1_criterion = nn.L1Loss(reduction='mean')
  L2_criterion = nn.MSELoss(reduction='mean')
  BCE_criterion = nn.BCELoss(reduction='mean')

  if is_cuda:
    L1_criterion.cuda()
    L2_criterion.cuda()
    BCE_criterion.cuda()

  loss_D_list = []
  loss_G_list = []

  for epoch in range(epochs):
    for i,data in enumerate(dataloader):
      X,_ = data
      y_real = torch.FloatTensor(batch_size).fill_(0)#real label=0,size=batch_size
      y_fake = torch.FloatTensor(batch_size).fill_(1)#fake label=1,size=batch_size
#2020921,real label 和fake label值的设置，是否会影响最终收敛结果？
#       y_real = torch.FloatTensor(batch_size).fill_(1)#real label=0,size=batch_size
#       y_fake = torch.FloatTensor(batch_size).fill_(0)#fake label=1,size=batch_size

      if is_cuda:
        X = X.cuda()
        y_real = y_real.cuda()
        y_fake = y_fake.cuda()

      X = Variable(X)
      y_real = Variable(y_real)
      y_fake = Variable(y_fake)

      #zero grad for discriminator
      net_discriminator.zero_grad()
      #training the discriminator with real sample
      _,output = net_discriminator(X)
      loss_D_real = BCE_criterion(output.view(-1),y_real)

      #training the discriminator with fake sample
      _,X_hat,_ = net_generator(X)
      _,output = net_discriminator(X_hat)

      loss_D_fake = BCE_criterion(output.view(-1),y_fake)

      #entire loss in discriminator
      loss_D = (loss_D_real+loss_D_fake)/2
      
      loss_D.backward()
      optimizer_D.step()

      #training the generator based on the result from the discriminator
      net_generator.zero_grad()

      z,X_hat,z_hat = net_generator(X)

      #latent loss
      feature_real,_ = net_discriminator(X)
      feature_fake,_ = net_discriminator(X_hat)

      loss_G_latent = L2_criterion(feature_fake,feature_real)
      
      #contexutal loss
      loss_G_contextual = L1_criterion(X,X_hat)
      #entire loss in generator

      #encoder loss
      loss_G_encoder = L1_criterion(z,z_hat)
      
      loss_G = (loss_G_latent + loss_G_contextual + loss_G_encoder)/3
      
      loss_G.backward()
      optimizer_G.step()

      if (i%50 == 0) & print_loss:
        print('[%d/%d] [%d/%d] Loss D: %.4f / Loss G: %.4f' % (epoch+1,epochs,i,len(dataloader),loss_D,loss_G))

      loss_D_list.append(loss_D)
      loss_G_list.append(loss_G)

# %%
def evaluation(data_tensor,model):
  if is_cuda:
    data_tensor = data_tensor.cuda()
    
  z,_,z_hat = model(data_tensor)

  L1_criterion = nn.L1Loss(reduction='none')
  score = L1_criterion(z,z_hat)
  score = torch.sum(score,dim=1).cpu().detach().numpy()
    
  return score

# %% [markdown]
# Global Parameters

# %%
seed_pool = [1,2,3,4,5]
anomaly_ratio_pool = [0.03,0.04,0.05]
contam_ratio_pool = [1.0,0.98,0.8,0.5,0.0]

#random search size
search_size = 10

# %%
epochs = 20
batch_size = 64

hyper_act_fun = [nn.Tanh(),nn.LeakyReLU()]
hyper_lr = [1e-2,1e-3,1e-4]
hyper_mom = [0.5,0.7,0.9]

hyper_list_entire = list(product(hyper_act_fun,hyper_lr,hyper_mom))

# %%
def random_search(hyper_list_entire,search_size,seed):
  if search_size < len(hyper_list_entire):
    set_seed(seed)
    index = np.random.choice(np.arange(len(hyper_list_entire)),search_size,replace = False)

    hyper_list = []
    for i in index:
      hyper_list.append(hyper_list_entire[i])
  else:
    hyper_list = hyper_list_entire

  return hyper_list

# %%
for contam_ratio in tqdm(contam_ratio_pool):  
  df_result = pd.DataFrame(data = None,index = ['AUCPR'] + anomaly_ratio_pool,columns = seed_pool)
  for seed in tqdm(seed_pool):
    #############################################seleting the best hyper-parameters in validation set#############################################
    metric_value_list=list()
    hyper_list = random_search(hyper_list_entire,search_size,seed)
    for i in range(len(hyper_list)):
      try:
        print(f'Finding Optimal Hyper-parameters......Current Candidates: {hyper_list[i]}')
        act_fun,lr,mom = hyper_list[i]
        #data
        train_loader,X_val_tensor,y_val,_,_ = data_prepare(batch_size,contam_ratio,hybrid = False,seed = seed)
        #model initialization
        set_seed(seed)
        net_generator=generator(input_size = X_val_tensor.size(1),act_fun = act_fun)
        net_discriminator=discriminator(input_size = X_val_tensor.size(1),act_fun = act_fun)

        if is_cuda:
          net_generator.cuda()
          net_discriminator.cuda()

        optimizer_G=torch.optim.SGD(net_generator.parameters(),lr = lr,momentum = mom)
        optimizer_D=torch.optim.SGD(net_discriminator.parameters(),lr = lr,momentum = mom)
        #fitting
        fit(dataloader = train_loader,net_generator = net_generator,net_discriminator = net_discriminator,
          epochs = epochs,batch_size = batch_size,print_loss = False)
        
        #evaluation
        score = evaluation(data_tensor = X_val_tensor,model = net_generator)
        metric_value = average_precision_score(y_true = y_val,y_score = score,pos_label = -1)
        metric_value_list.append(metric_value)

        print(f'The metric value corresponded to the hyper-parameters is :{metric_value:{.4}}')
        print('******************************')
        print('\n')
      except:
        #keep the right index
        metric_value_list.append(0)
        pass
      continue

    best_hyper_params=hyper_list[metric_value_list.index(max(metric_value_list))]
    print(f'The best hyper-parameters are: {best_hyper_params}')
    print('\n')
    ###################################################################testing#########################################################################
    print('Testing Phrase......')
    act_fun,lr,mom = best_hyper_params

    #data
    train_loader,_,_,X_test_tensor,y_test = data_prepare(batch_size,contam_ratio,hybrid = False,seed = seed)
    
    #model initialization, there exists randomness because of weight initialization***
    set_seed(seed)
    net_generator=generator(input_size = X_test_tensor.size(1),act_fun = act_fun)
    net_discriminator=discriminator(input_size = X_test_tensor.size(1),act_fun = act_fun)

    if is_cuda:
      net_generator.cuda()
      net_discriminator.cuda()

    optimizer_G = torch.optim.SGD(net_generator.parameters(),lr = lr,momentum = mom)
    optimizer_D = torch.optim.SGD(net_discriminator.parameters(),lr = lr,momentum = mom)
    #fitting
    fit(dataloader = train_loader,net_generator = net_generator,net_discriminator = net_discriminator,
      epochs = epochs,batch_size = batch_size,print_loss = False)
    #evaluation
    score = evaluation(data_tensor = X_test_tensor,model = net_generator)
    
    #store the result
    #AUCPR
    df_result.loc['AUCPR',seed] = average_precision_score(y_true = y_test,y_score = score,pos_label = -1)
    #F1
    for anomaly_ratio in anomaly_ratio_pool:
        threshold = score[np.argsort(-score)][int(anomaly_ratio*len(score))]
        
        y_pred = np.ones(len(score))
        y_pred[score >= threshold] = -1
        
        print('\n')
        print(f'Precision: {round(precision_score(y_pred = y_pred, y_true = y_test, pos_label= -1)*100,2)}')
        print(f'Recall: {round(recall_score(y_pred = y_pred, y_true = y_test, pos_label= -1)*100,2)}')
        print(f'F1-score: {round(f1_score(y_pred = y_pred, y_true = y_test, pos_label= -1)*100,2)}')
        print('\n')

        df_result.loc[anomaly_ratio,seed] = f1_score(y_pred = y_pred,y_true = y_test,pos_label = -1)

  #mean & sd
  df_result['mean'] = np.mean(df_result.loc[:,seed_pool],axis = 1)
  df_result['std'] = np.std(df_result.loc[:,seed_pool],axis = 1)
  df_result = round(df_result.astype('float64')*100,2)

  file_path = 'E:/Research_Anomaly Detection/Taiwanese Bankruptcy Prediction (TBP)/result/' + 'TBP_GAN_test' + str(contam_ratio) + '.csv'
  df_result.to_csv(file_path,index = False)
# Out:
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.0001, 0.5)
# The left true(known) positive samples in the training set:0/170
#
# The metric value corresponded to the hyper-parameters is :0.01094
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.001, 0.5)
# The left true(known) positive samples in the training set:0/170
#
# The metric value corresponded to the hyper-parameters is :0.01822
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.001, 0.7)
# The left true(known) positive samples in the training set:0/170
#
# The metric value corresponded to the hyper-parameters is :0.03552
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.01, 0.9)
# The left true(known) positive samples in the training set:0/170
#
# The metric value corresponded to the hyper-parameters is :0.03079
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.001, 0.9)
# The left true(known) positive samples in the training set:0/170
#
# The metric value corresponded to the hyper-parameters is :0.01404
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.0001, 0.7)
# The left true(known) positive samples in the training set:0/170
#
# The metric value corresponded to the hyper-parameters is :0.01171
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.0001, 0.5)
# The left true(known) positive samples in the training set:0/170
#
# The metric value corresponded to the hyper-parameters is :0.01446
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.001, 0.7)
# The left true(known) positive samples in the training set:0/170
#
# The metric value corresponded to the hyper-parameters is :0.01773
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.01, 0.7)
# The left true(known) positive samples in the training set:0/170
#
# The metric value corresponded to the hyper-parameters is :0.03203
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.01, 0.7)
# The left true(known) positive samples in the training set:0/170
#
# The metric value corresponded to the hyper-parameters is :0.01088
# ******************************
#
#
# The best hyper-parameters are: (LeakyReLU(negative_slope=0.01), 0.001, 0.7)
#
#
# Testing Phrase......
# The left true(known) positive samples in the training set:0/170
#  20%|████████████████▊                                                                   | 1/5 [00:33<02:12, 33.20s/it]
# Precision: 8.06
# Recall: 15.62
# F1-score: 10.64
#
#
#
#
# Precision: 13.41
# Recall: 34.38
# F1-score: 19.3
#
#
#
#
# Precision: 12.62
# Recall: 40.62
# F1-score: 19.26
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.01, 0.5)
# The left true(known) positive samples in the training set:0/170
#
# The metric value corresponded to the hyper-parameters is :0.01033
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.001, 0.7)
# The left true(known) positive samples in the training set:0/170
#
# The metric value corresponded to the hyper-parameters is :0.01268
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.0001, 0.7)
# The left true(known) positive samples in the training set:0/170
#
# The metric value corresponded to the hyper-parameters is :0.01045
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.01, 0.5)
# The left true(known) positive samples in the training set:0/170
#
# The metric value corresponded to the hyper-parameters is :0.01963
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.01, 0.7)
# The left true(known) positive samples in the training set:0/170
#
# The metric value corresponded to the hyper-parameters is :0.01579
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.001, 0.9)
# The left true(known) positive samples in the training set:0/170
#
# The metric value corresponded to the hyper-parameters is :0.0139
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.001, 0.5)
# The left true(known) positive samples in the training set:0/170
#
# The metric value corresponded to the hyper-parameters is :0.01322
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.01, 0.7)
# The left true(known) positive samples in the training set:0/170
#
# The metric value corresponded to the hyper-parameters is :0.0245
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.001, 0.5)
# The left true(known) positive samples in the training set:0/170
#
# The metric value corresponded to the hyper-parameters is :0.01565
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.0001, 0.7)
# The left true(known) positive samples in the training set:0/170
#
# The metric value corresponded to the hyper-parameters is :0.01121
# ******************************
#
#
# The best hyper-parameters are: (Tanh(), 0.01, 0.7)
#
#
# Testing Phrase......
# The left true(known) positive samples in the training set:0/170
#  40%|█████████████████████████████████▌                                                  | 2/5 [01:04<01:38, 32.71s/it]
# Precision: 3.23
# Recall: 6.25
# F1-score: 4.26
#
#
#
#
# Precision: 3.66
# Recall: 9.38
# F1-score: 5.26
#
#
#
#
# Precision: 2.91
# Recall: 9.38
# F1-score: 4.44
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.01, 0.9)
# The left true(known) positive samples in the training set:0/170
#
# The metric value corresponded to the hyper-parameters is :0.01289
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.01, 0.9)
# The left true(known) positive samples in the training set:0/170
#
# The metric value corresponded to the hyper-parameters is :0.03062
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.01, 0.7)
# The left true(known) positive samples in the training set:0/170
#
# The metric value corresponded to the hyper-parameters is :0.02608
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.001, 0.9)
# The left true(known) positive samples in the training set:0/170
#
# The metric value corresponded to the hyper-parameters is :0.02827
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.001, 0.7)
# The left true(known) positive samples in the training set:0/170
#
# The metric value corresponded to the hyper-parameters is :0.01699
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.001, 0.7)
# The left true(known) positive samples in the training set:0/170
#
# The metric value corresponded to the hyper-parameters is :0.01729
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.0001, 0.5)
# The left true(known) positive samples in the training set:0/170
#
# The metric value corresponded to the hyper-parameters is :0.01302
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.0001, 0.7)
# The left true(known) positive samples in the training set:0/170
#
# The metric value corresponded to the hyper-parameters is :0.01439
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.001, 0.5)
# The left true(known) positive samples in the training set:0/170
#
# The metric value corresponded to the hyper-parameters is :0.02091
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.01, 0.5)
# The left true(known) positive samples in the training set:0/170
#
# The metric value corresponded to the hyper-parameters is :0.02339
# ******************************
#
#
# The best hyper-parameters are: (Tanh(), 0.01, 0.9)
#
#
# Testing Phrase......
# The left true(known) positive samples in the training set:0/170
#  60%|██████████████████████████████████████████████████▍                                 | 3/5 [01:39<01:06, 33.23s/it]
# Precision: 1.61
# Recall: 3.12
# F1-score: 2.13
#
#
#
#
# Precision: 2.44
# Recall: 6.25
# F1-score: 3.51
#
#
#
#
# Precision: 2.91
# Recall: 9.38
# F1-score: 4.44
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.0001, 0.5)
# The left true(known) positive samples in the training set:0/170
#
# The metric value corresponded to the hyper-parameters is :0.01169
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.001, 0.5)
# The left true(known) positive samples in the training set:0/170
#
# The metric value corresponded to the hyper-parameters is :0.01513
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.0001, 0.7)
# The left true(known) positive samples in the training set:0/170
#
# The metric value corresponded to the hyper-parameters is :0.01196
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.01, 0.9)
# The left true(known) positive samples in the training set:0/170
#
# The metric value corresponded to the hyper-parameters is :0.015
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.001, 0.7)
# The left true(known) positive samples in the training set:0/170
#
# The metric value corresponded to the hyper-parameters is :0.01503
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.01, 0.5)
# The left true(known) positive samples in the training set:0/170
#
# The metric value corresponded to the hyper-parameters is :0.01878
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.0001, 0.5)
# The left true(known) positive samples in the training set:0/170
#
# The metric value corresponded to the hyper-parameters is :0.01167
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.001, 0.5)
# The left true(known) positive samples in the training set:0/170
#
# The metric value corresponded to the hyper-parameters is :0.01522
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.01, 0.7)
# The left true(known) positive samples in the training set:0/170
#
# The metric value corresponded to the hyper-parameters is :0.01494
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.001, 0.7)
# The left true(known) positive samples in the training set:0/170
#
# The metric value corresponded to the hyper-parameters is :0.01338
# ******************************
#
#
# The best hyper-parameters are: (Tanh(), 0.01, 0.5)
#
#
# Testing Phrase......
# The left true(known) positive samples in the training set:0/170
#  80%|███████████████████████████████████████████████████████████████████▏                | 4/5 [02:13<00:33, 33.66s/it]
# Precision: 0.0
# Recall: 0.0
# F1-score: 0.0
#
#
#
#
# Precision: 1.22
# Recall: 3.12
# F1-score: 1.75
#
#
#
#
# Precision: 0.97
# Recall: 3.12
# F1-score: 1.48
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.001, 0.9)
# The left true(known) positive samples in the training set:0/170
#
# The metric value corresponded to the hyper-parameters is :0.02287
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.01, 0.7)
# The left true(known) positive samples in the training set:0/170
#
# The metric value corresponded to the hyper-parameters is :0.03203
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.01, 0.7)
# The left true(known) positive samples in the training set:0/170
#
# The metric value corresponded to the hyper-parameters is :0.008764
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.01, 0.9)
# The left true(known) positive samples in the training set:0/170
#
# The metric value corresponded to the hyper-parameters is :0.03404
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.01, 0.9)
# The left true(known) positive samples in the training set:0/170
#
# The metric value corresponded to the hyper-parameters is :0.01968
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.0001, 0.9)
# The left true(known) positive samples in the training set:0/170
#
# The metric value corresponded to the hyper-parameters is :0.02273
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.001, 0.5)
# The left true(known) positive samples in the training set:0/170
#
# The metric value corresponded to the hyper-parameters is :0.01712
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.0001, 0.7)
# The left true(known) positive samples in the training set:0/170
#
# The metric value corresponded to the hyper-parameters is :0.01183
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.001, 0.7)
# The left true(known) positive samples in the training set:0/170
#
# The metric value corresponded to the hyper-parameters is :0.02031
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.0001, 0.9)
# The left true(known) positive samples in the training set:0/170
#
# The metric value corresponded to the hyper-parameters is :0.01274
# ******************************
#
#
# The best hyper-parameters are: (Tanh(), 0.01, 0.9)
#
#
# Testing Phrase......
# The left true(known) positive samples in the training set:0/170
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [02:49<00:00, 33.94s/it]
#  20%|████████████████▌                                                                  | 1/5 [02:49<11:18, 169.75s/it]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# Precision: 4.84
# Recall: 9.38
# F1-score: 6.38
#
#
#
#
# Precision: 4.88
# Recall: 12.5
# F1-score: 7.02
#
#
#
#
# Precision: 4.85
# Recall: 15.62
# F1-score: 7.41
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.0001, 0.5)
# The left true(known) positive samples in the training set:4/170
#
# The metric value corresponded to the hyper-parameters is :0.01095
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.001, 0.5)
# The left true(known) positive samples in the training set:4/170
#
# The metric value corresponded to the hyper-parameters is :0.01822
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.001, 0.7)
# The left true(known) positive samples in the training set:4/170
#
# The metric value corresponded to the hyper-parameters is :0.03593
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.01, 0.9)
# The left true(known) positive samples in the training set:4/170
#
# The metric value corresponded to the hyper-parameters is :0.03139
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.001, 0.9)
# The left true(known) positive samples in the training set:4/170
#
# The metric value corresponded to the hyper-parameters is :0.01377
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.0001, 0.7)
# The left true(known) positive samples in the training set:4/170
#
# The metric value corresponded to the hyper-parameters is :0.01171
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.0001, 0.5)
# The left true(known) positive samples in the training set:4/170
#
# The metric value corresponded to the hyper-parameters is :0.01446
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.001, 0.7)
# The left true(known) positive samples in the training set:4/170
#
# The metric value corresponded to the hyper-parameters is :0.01774
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.01, 0.7)
# The left true(known) positive samples in the training set:4/170
#
# The metric value corresponded to the hyper-parameters is :0.03228
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.01, 0.7)
# The left true(known) positive samples in the training set:4/170
#
# The metric value corresponded to the hyper-parameters is :0.01085
# ******************************
#
#
# The best hyper-parameters are: (LeakyReLU(negative_slope=0.01), 0.001, 0.7)
#
#
# Testing Phrase......
# The left true(known) positive samples in the training set:4/170
#  20%|████████████████▊                                                                   | 1/5 [00:32<02:09, 32.34s/it]
# Precision: 8.06
# Recall: 15.62
# F1-score: 10.64
#
#
#
#
# Precision: 13.41
# Recall: 34.38
# F1-score: 19.3
#
#
#
#
# Precision: 12.62
# Recall: 40.62
# F1-score: 19.26
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.01, 0.5)
# The left true(known) positive samples in the training set:4/170
#
# The metric value corresponded to the hyper-parameters is :0.01028
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.001, 0.7)
# The left true(known) positive samples in the training set:4/170
#
# The metric value corresponded to the hyper-parameters is :0.01269
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.0001, 0.7)
# The left true(known) positive samples in the training set:4/170
#
# The metric value corresponded to the hyper-parameters is :0.01045
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.01, 0.5)
# The left true(known) positive samples in the training set:4/170
#
# The metric value corresponded to the hyper-parameters is :0.01959
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.01, 0.7)
# The left true(known) positive samples in the training set:4/170
#
# The metric value corresponded to the hyper-parameters is :0.01575
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.001, 0.9)
# The left true(known) positive samples in the training set:4/170
#
# The metric value corresponded to the hyper-parameters is :0.01394
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.001, 0.5)
# The left true(known) positive samples in the training set:4/170
#
# The metric value corresponded to the hyper-parameters is :0.01325
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.01, 0.7)
# The left true(known) positive samples in the training set:4/170
#
# The metric value corresponded to the hyper-parameters is :0.02444
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.001, 0.5)
# The left true(known) positive samples in the training set:4/170
#
# The metric value corresponded to the hyper-parameters is :0.01566
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.0001, 0.7)
# The left true(known) positive samples in the training set:4/170
#
# The metric value corresponded to the hyper-parameters is :0.01121
# ******************************
#
#
# The best hyper-parameters are: (Tanh(), 0.01, 0.7)
#
#
# Testing Phrase......
# The left true(known) positive samples in the training set:4/170
#  40%|█████████████████████████████████▌                                                  | 2/5 [01:04<01:36, 32.27s/it]
# Precision: 1.61
# Recall: 3.12
# F1-score: 2.13
#
#
#
#
# Precision: 3.66
# Recall: 9.38
# F1-score: 5.26
#
#
#
#
# Precision: 2.91
# Recall: 9.38
# F1-score: 4.44
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.01, 0.9)
# The left true(known) positive samples in the training set:4/170
#
# The metric value corresponded to the hyper-parameters is :0.01396
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.01, 0.9)
# The left true(known) positive samples in the training set:4/170
#
# The metric value corresponded to the hyper-parameters is :0.03084
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.01, 0.7)
# The left true(known) positive samples in the training set:4/170
#
# The metric value corresponded to the hyper-parameters is :0.02613
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.001, 0.9)
# The left true(known) positive samples in the training set:4/170
#
# The metric value corresponded to the hyper-parameters is :0.02829
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.001, 0.7)
# The left true(known) positive samples in the training set:4/170
#
# The metric value corresponded to the hyper-parameters is :0.01698
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.001, 0.7)
# The left true(known) positive samples in the training set:4/170
#
# The metric value corresponded to the hyper-parameters is :0.01726
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.0001, 0.5)
# The left true(known) positive samples in the training set:4/170
#
# The metric value corresponded to the hyper-parameters is :0.01303
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.0001, 0.7)
# The left true(known) positive samples in the training set:4/170
#
# The metric value corresponded to the hyper-parameters is :0.01439
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.001, 0.5)
# The left true(known) positive samples in the training set:4/170
#
# The metric value corresponded to the hyper-parameters is :0.02091
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.01, 0.5)
# The left true(known) positive samples in the training set:4/170
#
# The metric value corresponded to the hyper-parameters is :0.02316
# ******************************
#
#
# The best hyper-parameters are: (Tanh(), 0.01, 0.9)
#
#
# Testing Phrase......
# The left true(known) positive samples in the training set:4/170
#  60%|██████████████████████████████████████████████████▍                                 | 3/5 [01:36<01:04, 32.30s/it]
# Precision: 1.61
# Recall: 3.12
# F1-score: 2.13
#
#
#
#
# Precision: 2.44
# Recall: 6.25
# F1-score: 3.51
#
#
#
#
# Precision: 2.91
# Recall: 9.38
# F1-score: 4.44
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.0001, 0.5)
# The left true(known) positive samples in the training set:4/170
#
# The metric value corresponded to the hyper-parameters is :0.01169
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.001, 0.5)
# The left true(known) positive samples in the training set:4/170
#
# The metric value corresponded to the hyper-parameters is :0.01512
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.0001, 0.7)
# The left true(known) positive samples in the training set:4/170
#
# The metric value corresponded to the hyper-parameters is :0.01196
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.01, 0.9)
# The left true(known) positive samples in the training set:4/170
#
# The metric value corresponded to the hyper-parameters is :0.01418
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.001, 0.7)
# The left true(known) positive samples in the training set:4/170
#
# The metric value corresponded to the hyper-parameters is :0.01504
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.01, 0.5)
# The left true(known) positive samples in the training set:4/170
#
# The metric value corresponded to the hyper-parameters is :0.01878
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.0001, 0.5)
# The left true(known) positive samples in the training set:4/170
#
# The metric value corresponded to the hyper-parameters is :0.01167
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.001, 0.5)
# The left true(known) positive samples in the training set:4/170
#
# The metric value corresponded to the hyper-parameters is :0.01523
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.01, 0.7)
# The left true(known) positive samples in the training set:4/170
#
# The metric value corresponded to the hyper-parameters is :0.01511
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.001, 0.7)
# The left true(known) positive samples in the training set:4/170
#
# The metric value corresponded to the hyper-parameters is :0.01338
# ******************************
#
#
# The best hyper-parameters are: (Tanh(), 0.01, 0.5)
#
#
# Testing Phrase......
# The left true(known) positive samples in the training set:4/170
#  80%|███████████████████████████████████████████████████████████████████▏                | 4/5 [02:09<00:32, 32.34s/it]
# Precision: 0.0
# Recall: 0.0
# F1-score: 0.0
#
#
#
#
# Precision: 1.22
# Recall: 3.12
# F1-score: 1.75
#
#
#
#
# Precision: 0.97
# Recall: 3.12
# F1-score: 1.48
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.001, 0.9)
# The left true(known) positive samples in the training set:4/170
#
# The metric value corresponded to the hyper-parameters is :0.02282
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.01, 0.7)
# The left true(known) positive samples in the training set:4/170
#
# The metric value corresponded to the hyper-parameters is :0.03198
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.01, 0.7)
# The left true(known) positive samples in the training set:4/170
#
# The metric value corresponded to the hyper-parameters is :0.00876
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.01, 0.9)
# The left true(known) positive samples in the training set:4/170
#
# The metric value corresponded to the hyper-parameters is :0.03346
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.01, 0.9)
# The left true(known) positive samples in the training set:4/170
#
# The metric value corresponded to the hyper-parameters is :0.01945
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.0001, 0.9)
# The left true(known) positive samples in the training set:4/170
#
# The metric value corresponded to the hyper-parameters is :0.02274
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.001, 0.5)
# The left true(known) positive samples in the training set:4/170
#
# The metric value corresponded to the hyper-parameters is :0.01708
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.0001, 0.7)
# The left true(known) positive samples in the training set:4/170
#
# The metric value corresponded to the hyper-parameters is :0.01183
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.001, 0.7)
# The left true(known) positive samples in the training set:4/170
#
# The metric value corresponded to the hyper-parameters is :0.02033
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.0001, 0.9)
# The left true(known) positive samples in the training set:4/170
#
# The metric value corresponded to the hyper-parameters is :0.01274
# ******************************
#
#
# The best hyper-parameters are: (Tanh(), 0.01, 0.9)
#
#
# Testing Phrase......
# The left true(known) positive samples in the training set:4/170
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [02:43<00:00, 32.65s/it]
#  40%|█████████████████████████████████▏                                                 | 2/5 [05:33<08:23, 167.80s/it]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# Precision: 4.84
# Recall: 9.38
# F1-score: 6.38
#
#
#
#
# Precision: 4.88
# Recall: 12.5
# F1-score: 7.02
#
#
#
#
# Precision: 4.85
# Recall: 15.62
# F1-score: 7.41
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.0001, 0.5)
# The left true(known) positive samples in the training set:34/170
#
# The metric value corresponded to the hyper-parameters is :0.01092
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.001, 0.5)
# The left true(known) positive samples in the training set:34/170
#
# The metric value corresponded to the hyper-parameters is :0.01828
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.001, 0.7)
# The left true(known) positive samples in the training set:34/170
#
# The metric value corresponded to the hyper-parameters is :0.03616
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.01, 0.9)
# The left true(known) positive samples in the training set:34/170
#
# The metric value corresponded to the hyper-parameters is :0.02938
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.001, 0.9)
# The left true(known) positive samples in the training set:34/170
#
# The metric value corresponded to the hyper-parameters is :0.01332
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.0001, 0.7)
# The left true(known) positive samples in the training set:34/170
#
# The metric value corresponded to the hyper-parameters is :0.01165
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.0001, 0.5)
# The left true(known) positive samples in the training set:34/170
#
# The metric value corresponded to the hyper-parameters is :0.01441
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.001, 0.7)
# The left true(known) positive samples in the training set:34/170
#
# The metric value corresponded to the hyper-parameters is :0.01775
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.01, 0.7)
# The left true(known) positive samples in the training set:34/170
#
# The metric value corresponded to the hyper-parameters is :0.032
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.01, 0.7)
# The left true(known) positive samples in the training set:34/170
#
# The metric value corresponded to the hyper-parameters is :0.01085
# ******************************
#
#
# The best hyper-parameters are: (LeakyReLU(negative_slope=0.01), 0.001, 0.7)
#
#
# Testing Phrase......
# The left true(known) positive samples in the training set:34/170
#  20%|████████████████▊                                                                   | 1/5 [00:32<02:09, 32.46s/it]
# Precision: 9.68
# Recall: 18.75
# F1-score: 12.77
#
#
#
#
# Precision: 13.41
# Recall: 34.38
# F1-score: 19.3
#
#
#
#
# Precision: 13.59
# Recall: 43.75
# F1-score: 20.74
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.01, 0.5)
# The left true(known) positive samples in the training set:34/170
#
# The metric value corresponded to the hyper-parameters is :0.0103
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.001, 0.7)
# The left true(known) positive samples in the training set:34/170
#
# The metric value corresponded to the hyper-parameters is :0.01268
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.0001, 0.7)
# The left true(known) positive samples in the training set:34/170
#
# The metric value corresponded to the hyper-parameters is :0.01032
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.01, 0.5)
# The left true(known) positive samples in the training set:34/170
#
# The metric value corresponded to the hyper-parameters is :0.01916
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.01, 0.7)
# The left true(known) positive samples in the training set:34/170
#
# The metric value corresponded to the hyper-parameters is :0.01569
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.001, 0.9)
# The left true(known) positive samples in the training set:34/170
#
# The metric value corresponded to the hyper-parameters is :0.01363
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.001, 0.5)
# The left true(known) positive samples in the training set:34/170
#
# The metric value corresponded to the hyper-parameters is :0.01327
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.01, 0.7)
# The left true(known) positive samples in the training set:34/170
#
# The metric value corresponded to the hyper-parameters is :0.02426
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.001, 0.5)
# The left true(known) positive samples in the training set:34/170
#
# The metric value corresponded to the hyper-parameters is :0.01558
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.0001, 0.7)
# The left true(known) positive samples in the training set:34/170
#
# The metric value corresponded to the hyper-parameters is :0.01104
# ******************************
#
#
# The best hyper-parameters are: (Tanh(), 0.01, 0.7)
#
#
# Testing Phrase......
# The left true(known) positive samples in the training set:34/170
#  40%|█████████████████████████████████▌                                                  | 2/5 [01:04<01:36, 32.26s/it]
# Precision: 3.23
# Recall: 6.25
# F1-score: 4.26
#
#
#
#
# Precision: 3.66
# Recall: 9.38
# F1-score: 5.26
#
#
#
#
# Precision: 2.91
# Recall: 9.38
# F1-score: 4.44
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.01, 0.9)
# The left true(known) positive samples in the training set:34/170
#
# The metric value corresponded to the hyper-parameters is :0.01463
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.01, 0.9)
# The left true(known) positive samples in the training set:34/170
#
# The metric value corresponded to the hyper-parameters is :0.0342
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.01, 0.7)
# The left true(known) positive samples in the training set:34/170
#
# The metric value corresponded to the hyper-parameters is :0.02628
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.001, 0.9)
# The left true(known) positive samples in the training set:34/170
#
# The metric value corresponded to the hyper-parameters is :0.02894
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.001, 0.7)
# The left true(known) positive samples in the training set:34/170
#
# The metric value corresponded to the hyper-parameters is :0.01724
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.001, 0.7)
# The left true(known) positive samples in the training set:34/170
#
# The metric value corresponded to the hyper-parameters is :0.01796
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.0001, 0.5)
# The left true(known) positive samples in the training set:34/170
#
# The metric value corresponded to the hyper-parameters is :0.013
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.0001, 0.7)
# The left true(known) positive samples in the training set:34/170
#
# The metric value corresponded to the hyper-parameters is :0.01439
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.001, 0.5)
# The left true(known) positive samples in the training set:34/170
#
# The metric value corresponded to the hyper-parameters is :0.02101
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.01, 0.5)
# The left true(known) positive samples in the training set:34/170
#
# The metric value corresponded to the hyper-parameters is :0.02435
# ******************************
#
#
# The best hyper-parameters are: (Tanh(), 0.01, 0.9)
#
#
# Testing Phrase......
# The left true(known) positive samples in the training set:34/170
#  60%|██████████████████████████████████████████████████▍                                 | 3/5 [01:36<01:04, 32.18s/it]
# Precision: 1.61
# Recall: 3.12
# F1-score: 2.13
#
#
#
#
# Precision: 2.44
# Recall: 6.25
# F1-score: 3.51
#
#
#
#
# Precision: 2.91
# Recall: 9.38
# F1-score: 4.44
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.0001, 0.5)
# The left true(known) positive samples in the training set:34/170
#
# The metric value corresponded to the hyper-parameters is :0.01168
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.001, 0.5)
# The left true(known) positive samples in the training set:34/170
#
# The metric value corresponded to the hyper-parameters is :0.01511
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.0001, 0.7)
# The left true(known) positive samples in the training set:34/170
#
# The metric value corresponded to the hyper-parameters is :0.01187
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.01, 0.9)
# The left true(known) positive samples in the training set:34/170
#
# The metric value corresponded to the hyper-parameters is :0.01386
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.001, 0.7)
# The left true(known) positive samples in the training set:34/170
#
# The metric value corresponded to the hyper-parameters is :0.01503
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.01, 0.5)
# The left true(known) positive samples in the training set:34/170
#
# The metric value corresponded to the hyper-parameters is :0.01771
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.0001, 0.5)
# The left true(known) positive samples in the training set:34/170
#
# The metric value corresponded to the hyper-parameters is :0.01166
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.001, 0.5)
# The left true(known) positive samples in the training set:34/170
#
# The metric value corresponded to the hyper-parameters is :0.01523
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.01, 0.7)
# The left true(known) positive samples in the training set:34/170
#
# The metric value corresponded to the hyper-parameters is :0.01446
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.001, 0.7)
# The left true(known) positive samples in the training set:34/170
#
# The metric value corresponded to the hyper-parameters is :0.01342
# ******************************
#
#
# The best hyper-parameters are: (Tanh(), 0.01, 0.5)
#
#
# Testing Phrase......
# The left true(known) positive samples in the training set:34/170
#  80%|███████████████████████████████████████████████████████████████████▏                | 4/5 [02:08<00:32, 32.16s/it]
# Precision: 0.0
# Recall: 0.0
# F1-score: 0.0
#
#
#
#
# Precision: 1.22
# Recall: 3.12
# F1-score: 1.75
#
#
#
#
# Precision: 0.97
# Recall: 3.12
# F1-score: 1.48
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.001, 0.9)
# The left true(known) positive samples in the training set:34/170
#
# The metric value corresponded to the hyper-parameters is :0.02276
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.01, 0.7)
# The left true(known) positive samples in the training set:34/170
#
# The metric value corresponded to the hyper-parameters is :0.02982
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.01, 0.7)
# The left true(known) positive samples in the training set:34/170
#
# The metric value corresponded to the hyper-parameters is :0.008807
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.01, 0.9)
# The left true(known) positive samples in the training set:34/170
#
# The metric value corresponded to the hyper-parameters is :0.03452
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.01, 0.9)
# The left true(known) positive samples in the training set:34/170
#
# The metric value corresponded to the hyper-parameters is :0.01936
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.0001, 0.9)
# The left true(known) positive samples in the training set:34/170
#
# The metric value corresponded to the hyper-parameters is :0.02269
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.001, 0.5)
# The left true(known) positive samples in the training set:34/170
#
# The metric value corresponded to the hyper-parameters is :0.01698
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.0001, 0.7)
# The left true(known) positive samples in the training set:34/170
#
# The metric value corresponded to the hyper-parameters is :0.01181
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.001, 0.7)
# The left true(known) positive samples in the training set:34/170
#
# The metric value corresponded to the hyper-parameters is :0.0203
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.0001, 0.9)
# The left true(known) positive samples in the training set:34/170
#
# The metric value corresponded to the hyper-parameters is :0.01265
# ******************************
#
#
# The best hyper-parameters are: (Tanh(), 0.01, 0.9)
#
#
# Testing Phrase......
# The left true(known) positive samples in the training set:34/170
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [02:40<00:00, 32.13s/it]
#  60%|█████████████████████████████████████████████████▊                                 | 3/5 [08:13<05:31, 165.66s/it]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# Precision: 4.84
# Recall: 9.38
# F1-score: 6.38
#
#
#
#
# Precision: 4.88
# Recall: 12.5
# F1-score: 7.02
#
#
#
#
# Precision: 4.85
# Recall: 15.62
# F1-score: 7.41
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.0001, 0.5)
# The left true(known) positive samples in the training set:85/170
#
# The metric value corresponded to the hyper-parameters is :0.0109
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.001, 0.5)
# The left true(known) positive samples in the training set:85/170
#
# The metric value corresponded to the hyper-parameters is :0.01833
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.001, 0.7)
# The left true(known) positive samples in the training set:85/170
#
# The metric value corresponded to the hyper-parameters is :0.03534
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.01, 0.9)
# The left true(known) positive samples in the training set:85/170
#
# The metric value corresponded to the hyper-parameters is :0.02617
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.001, 0.9)
# The left true(known) positive samples in the training set:85/170
#
# The metric value corresponded to the hyper-parameters is :0.01341
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.0001, 0.7)
# The left true(known) positive samples in the training set:85/170
#
# The metric value corresponded to the hyper-parameters is :0.01161
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.0001, 0.5)
# The left true(known) positive samples in the training set:85/170
#
# The metric value corresponded to the hyper-parameters is :0.0144
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.001, 0.7)
# The left true(known) positive samples in the training set:85/170
#
# The metric value corresponded to the hyper-parameters is :0.0178
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.01, 0.7)
# The left true(known) positive samples in the training set:85/170
#
# The metric value corresponded to the hyper-parameters is :0.03288
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.01, 0.7)
# The left true(known) positive samples in the training set:85/170
#
# The metric value corresponded to the hyper-parameters is :0.01064
# ******************************
#
#
# The best hyper-parameters are: (LeakyReLU(negative_slope=0.01), 0.001, 0.7)
#
#
# Testing Phrase......
# The left true(known) positive samples in the training set:85/170
# ...
#
# The metric value corresponded to the hyper-parameters is :0.02042
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.0001, 0.9)
# The left true(known) positive samples in the training set:85/170
#
# The metric value corresponded to the hyper-parameters is :0.01261
# ******************************
#
#
# The best hyper-parameters are: (Tanh(), 0.01, 0.9)
#
#
# Testing Phrase......
# The left true(known) positive samples in the training set:85/170
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [02:42<00:00, 32.59s/it]
#  80%|██████████████████████████████████████████████████████████████████▍                | 4/5 [10:56<02:44, 164.86s/it]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# Precision: 4.84
# Recall: 9.38
# F1-score: 6.38
#
#
#
#
# Precision: 4.88
# Recall: 12.5
# F1-score: 7.02
#
#
#
#
# Precision: 4.85
# Recall: 15.62
# F1-score: 7.41
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.0001, 0.5)
# The left true(known) positive samples in the training set:170/170
#
# The metric value corresponded to the hyper-parameters is :0.01091
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.001, 0.5)
# The left true(known) positive samples in the training set:170/170
#
# The metric value corresponded to the hyper-parameters is :0.01843
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.001, 0.7)
# The left true(known) positive samples in the training set:170/170
#
# The metric value corresponded to the hyper-parameters is :0.0356
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.01, 0.9)
# The left true(known) positive samples in the training set:170/170
#
# The metric value corresponded to the hyper-parameters is :0.03109
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.001, 0.9)
# The left true(known) positive samples in the training set:170/170
#
# The metric value corresponded to the hyper-parameters is :0.01369
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.0001, 0.7)
# The left true(known) positive samples in the training set:170/170
#
# The metric value corresponded to the hyper-parameters is :0.01158
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.0001, 0.5)
# The left true(known) positive samples in the training set:170/170
#
# The metric value corresponded to the hyper-parameters is :0.01439
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.001, 0.7)
# The left true(known) positive samples in the training set:170/170
#
# The metric value corresponded to the hyper-parameters is :0.01794
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.01, 0.7)
# The left true(known) positive samples in the training set:170/170
#
# The metric value corresponded to the hyper-parameters is :0.03292
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.01, 0.7)
# The left true(known) positive samples in the training set:170/170
#
# The metric value corresponded to the hyper-parameters is :0.01289
# ******************************
#
#
# The best hyper-parameters are: (LeakyReLU(negative_slope=0.01), 0.001, 0.7)
#
#
# Testing Phrase......
# The left true(known) positive samples in the training set:170/170
#  20%|████████████████▊                                                                   | 1/5 [00:32<02:08, 32.17s/it]
# Precision: 11.29
# Recall: 21.88
# F1-score: 14.89
#
#
#
#
# Precision: 13.41
# Recall: 34.38
# F1-score: 19.3
#
#
#
#
# Precision: 13.59
# Recall: 43.75
# F1-score: 20.74
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.01, 0.5)
# The left true(known) positive samples in the training set:170/170
#
# The metric value corresponded to the hyper-parameters is :0.01038
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.001, 0.7)
# The left true(known) positive samples in the training set:170/170
#
# The metric value corresponded to the hyper-parameters is :0.01285
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.0001, 0.7)
# The left true(known) positive samples in the training set:170/170
#
# The metric value corresponded to the hyper-parameters is :0.01015
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.01, 0.5)
# The left true(known) positive samples in the training set:170/170
#
# The metric value corresponded to the hyper-parameters is :0.01947
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.01, 0.7)
# The left true(known) positive samples in the training set:170/170
#
# The metric value corresponded to the hyper-parameters is :0.01615
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.001, 0.9)
# The left true(known) positive samples in the training set:170/170
#
# The metric value corresponded to the hyper-parameters is :0.01365
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.001, 0.5)
# The left true(known) positive samples in the training set:170/170
#
# The metric value corresponded to the hyper-parameters is :0.01354
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.01, 0.7)
# The left true(known) positive samples in the training set:170/170
#
# The metric value corresponded to the hyper-parameters is :0.02462
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.001, 0.5)
# The left true(known) positive samples in the training set:170/170
#
# The metric value corresponded to the hyper-parameters is :0.01565
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.0001, 0.7)
# The left true(known) positive samples in the training set:170/170
#
# The metric value corresponded to the hyper-parameters is :0.01075
# ******************************
#
#
# The best hyper-parameters are: (Tanh(), 0.01, 0.7)
#
#
# Testing Phrase......
# The left true(known) positive samples in the training set:170/170
#  40%|█████████████████████████████████▌                                                  | 2/5 [01:05<01:37, 32.48s/it]
# Precision: 3.23
# Recall: 6.25
# F1-score: 4.26
#
#
#
#
# Precision: 3.66
# Recall: 9.38
# F1-score: 5.26
#
#
#
#
# Precision: 2.91
# Recall: 9.38
# F1-score: 4.44
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.01, 0.9)
# The left true(known) positive samples in the training set:170/170
#
# The metric value corresponded to the hyper-parameters is :0.0148
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.01, 0.9)
# The left true(known) positive samples in the training set:170/170
#
# The metric value corresponded to the hyper-parameters is :0.03645
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.01, 0.7)
# The left true(known) positive samples in the training set:170/170
#
# The metric value corresponded to the hyper-parameters is :0.02646
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.001, 0.9)
# The left true(known) positive samples in the training set:170/170
#
# The metric value corresponded to the hyper-parameters is :0.02939
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.001, 0.7)
# The left true(known) positive samples in the training set:170/170
#
# The metric value corresponded to the hyper-parameters is :0.0175
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.001, 0.7)
# The left true(known) positive samples in the training set:170/170
#
# The metric value corresponded to the hyper-parameters is :0.01833
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.0001, 0.5)
# The left true(known) positive samples in the training set:170/170
#
# The metric value corresponded to the hyper-parameters is :0.01293
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.0001, 0.7)
# The left true(known) positive samples in the training set:170/170
#
# The metric value corresponded to the hyper-parameters is :0.01435
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.001, 0.5)
# The left true(known) positive samples in the training set:170/170
#
# The metric value corresponded to the hyper-parameters is :0.02112
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.01, 0.5)
# The left true(known) positive samples in the training set:170/170
#
# The metric value corresponded to the hyper-parameters is :0.02443
# ******************************
#
#
# The best hyper-parameters are: (Tanh(), 0.01, 0.9)
#
#
# Testing Phrase......
# The left true(known) positive samples in the training set:170/170
#  60%|██████████████████████████████████████████████████▍                                 | 3/5 [01:49<01:11, 35.94s/it]
# Precision: 1.61
# Recall: 3.12
# F1-score: 2.13
#
#
#
#
# Precision: 3.66
# Recall: 9.38
# F1-score: 5.26
#
#
#
#
# Precision: 2.91
# Recall: 9.38
# F1-score: 4.44
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.0001, 0.5)
# The left true(known) positive samples in the training set:170/170
#
# The metric value corresponded to the hyper-parameters is :0.01165
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.001, 0.5)
# The left true(known) positive samples in the training set:170/170
#
# The metric value corresponded to the hyper-parameters is :0.01527
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.0001, 0.7)
# The left true(known) positive samples in the training set:170/170
#
# The metric value corresponded to the hyper-parameters is :0.01175
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.01, 0.9)
# The left true(known) positive samples in the training set:170/170
#
# The metric value corresponded to the hyper-parameters is :0.01492
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.001, 0.7)
# The left true(known) positive samples in the training set:170/170
#
# The metric value corresponded to the hyper-parameters is :0.01522
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.01, 0.5)
# The left true(known) positive samples in the training set:170/170
#
# The metric value corresponded to the hyper-parameters is :0.01817
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.0001, 0.5)
# The left true(known) positive samples in the training set:170/170
#
# The metric value corresponded to the hyper-parameters is :0.01163
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.001, 0.5)
# The left true(known) positive samples in the training set:170/170
#
# The metric value corresponded to the hyper-parameters is :0.01528
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.01, 0.7)
# The left true(known) positive samples in the training set:170/170
#
# The metric value corresponded to the hyper-parameters is :0.01483
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.001, 0.7)
# The left true(known) positive samples in the training set:170/170
#
# The metric value corresponded to the hyper-parameters is :0.01352
# ******************************
#
#
# The best hyper-parameters are: (Tanh(), 0.01, 0.5)
#
#
# Testing Phrase......
# The left true(known) positive samples in the training set:170/170
#  80%|███████████████████████████████████████████████████████████████████▏                | 4/5 [02:24<00:35, 35.74s/it]
# Precision: 0.0
# Recall: 0.0
# F1-score: 0.0
#
#
#
#
# Precision: 1.22
# Recall: 3.12
# F1-score: 1.75
#
#
#
#
# Precision: 0.97
# Recall: 3.12
# F1-score: 1.48
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.001, 0.9)
# The left true(known) positive samples in the training set:170/170
#
# The metric value corresponded to the hyper-parameters is :0.0229
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.01, 0.7)
# The left true(known) positive samples in the training set:170/170
#
# The metric value corresponded to the hyper-parameters is :0.03103
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.01, 0.7)
# The left true(known) positive samples in the training set:170/170
#
# The metric value corresponded to the hyper-parameters is :0.008862
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.01, 0.9)
# The left true(known) positive samples in the training set:170/170
#
# The metric value corresponded to the hyper-parameters is :0.03442
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.01, 0.9)
# The left true(known) positive samples in the training set:170/170
#
# The metric value corresponded to the hyper-parameters is :0.01654
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.0001, 0.9)
# The left true(known) positive samples in the training set:170/170
#
# The metric value corresponded to the hyper-parameters is :0.02267
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (LeakyReLU(negative_slope=0.01), 0.001, 0.5)
# The left true(known) positive samples in the training set:170/170
#
# The metric value corresponded to the hyper-parameters is :0.01694
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.0001, 0.7)
# The left true(known) positive samples in the training set:170/170
#
# The metric value corresponded to the hyper-parameters is :0.01182
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.001, 0.7)
# The left true(known) positive samples in the training set:170/170
#
# The metric value corresponded to the hyper-parameters is :0.02069
# ******************************
#
#
# Finding Optimal Hyper-parameters......Current Candidates: (Tanh(), 0.0001, 0.9)
# The left true(known) positive samples in the training set:170/170
#
# The metric value corresponded to the hyper-parameters is :0.01263
# ******************************
#
#
# The best hyper-parameters are: (Tanh(), 0.01, 0.9)
#
#
# Testing Phrase......
# The left true(known) positive samples in the training set:170/170
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [02:57<00:00, 35.52s/it]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [13:54<00:00, 166.86s/it]
# Precision: 4.84
# Recall: 9.38
# F1-score: 6.38
#
#
#
#
# Precision: 4.88
# Recall: 12.5
# F1-score: 7.02
#
#
#
#
# Precision: 4.85
# Recall: 15.62
# F1-score: 7.41

# %%
df_result
# Out:
#            1     2     3     4     5  mean   std
# AUCPR   9.34  3.27  2.92  1.82  2.91  4.05  2.69
# 0.03   14.89  4.26  2.13  0.00  6.38  5.53  5.14
# 0.04   19.30  5.26  5.26  1.75  7.02  7.72  6.04
# 0.05   20.74  4.44  4.44  1.48  7.41  7.70  6.78
